# %%
#Cargamos a nuestro entorno las librerias necesarias

import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
import numpy as np
import pandas as pd
data = pd.read_csv('data.csv', sep=",")
data
metros = data.groupby(['precio']).count()['metro']
metros
plt.plot(metros)
plt.tittle("Grafica de Lineas")
plt.xlabel("Metros")
plt.ylabel("Precio por metros")

text(0,0.6, 'metros')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 13
#      11 metros
#      12 plt.plot(metros)
# ---> 13 plt.tittle("Grafica de Lineas")
#      14 plt.xlabel("Metros")
#      15 plt.ylabel("Precio por metros")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tittle'
