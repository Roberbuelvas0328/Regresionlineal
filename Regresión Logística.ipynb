# %%
#Cargamos a nuestro entorno las librerias necesarias

import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
import numpy as np
import pandas as pd
data = pd.read_csv('framingham.csv', sep=",")
data
edad = data.groupby(['age']).count()['male']
edad
plt.plot(edad)
plt.tittle("Grafica de Lineas")
plt.xlabel("Edades")
plt.ylabel("Cantidad de Hombres")

text(0,0.5, 'edad')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 13
#      11 edad
#      12 plt.plot(edad)
# ---> 13 plt.tittle("Grafica de Lineas")
#      14 plt.xlabel("Edades")
#      15 plt.ylabel("Cantidad de Hombres")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tittle'
